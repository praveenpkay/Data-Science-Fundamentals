# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize']=8,4

# %%
x=range(1,10)
y=[1,2,3,4,0.5,4,3,2,1]
plt.bar(x,y)
plt.xlabel('Your X axis')
plt.ylabel('Your Y axis')
# Out:
# Text(0, 0.5, 'Your Y axis')

# %%
z=[1,2,3,4,0.5]
veh_type = ['bicycle','car','truck','bus','train']
plt.pie(z,labels=veh_type)
plt.show()

# %%
address='C:/Users/Praveenkumar/Desktop/Data Science/4 Data Visualization/mtcars.csv'
cars=pd.read_csv(address)
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

# %%
mpg =cars.mpg
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60,fontsize='medium')
ax.set_title('mpg of cars in mtcars dataset')
ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')
# Out:
# Text(0, 0.5, 'miles/gal')

# %%
#add legend
plt.pie(z)
plt.legend(veh_type)

# %%
#object method

fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60,fontsize='medium')
ax.set_title('mpg of cars in mtcars dataset')
ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')
ax.legend(loc='best')

# %%
#annoatating plot
mpg.max()
# Out:
# 33.9

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60,fontsize='medium')
ax.set_title('mpg of cars in mtcars dataset')
ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')
ax.legend(loc='best')
ax.set_ylim([0,45])
ax.annotate('Toyota Corolla', xy= (19,33.9), xytext=(21,35),arrowprops=dict(facecolor='black',shrink=0.05))
# Out:
# Text(21, 35, 'Toyota Corolla')

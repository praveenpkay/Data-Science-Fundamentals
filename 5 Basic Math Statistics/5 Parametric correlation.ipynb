# %%
"""
pearson correlation 
#correlation does not imply causation
# R=1 strong +ve relationship
# R=-1 -ve
# R=0 not linearly correlated
# assumes variables are normally distributed, continous numeric variables, inearly related

"""
import numpy as np
from numpy.random import randn
import pandas as pd

import seaborn as sb
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

from pylab import rcParams
import scipy
from scipy.stats.stats import pearsonr

# %%
#pearson correlation

# %matplotlib inline
rcParams['figure.figsize']= 8,4
plt.style.use('seaborn-whitegrid')

address='C:/Users/Praveenkumar/Desktop/Data Science/5 Basic Math Statistics/mtcars.csv'
cars=pd.read_csv(address)
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

sb.pairplot(cars)

# %%
X = cars[['mpg','hp','qsec','wt']]
sb.pairplot(X)

# %%
mpg = cars['mpg']
hp = cars['hp']
qsec = cars['qsec']
wt = cars['wt']

pearsonr_coefficient, p_value =pearsonr(mpg,hp)
print('PearsonR correlation coefficient %0.3f'%(pearsonr_coefficient))
# Out:
# PearsonR correlation coefficient -0.776

# %%
pearsonr_coefficient, p_value =pearsonr(mpg,qsec)
print('PearsonR correlation coefficient %0.3f'%(pearsonr_coefficient))
# Out:
# PearsonR correlation coefficient 0.419

# %%
pearsonr_coefficient, p_value =pearsonr(mpg,wt)
print('PearsonR correlation coefficient %0.3f'%(pearsonr_coefficient))
# Out:
# PearsonR correlation coefficient -0.868

# %%
#using pandas 
corr = X.corr()
corr
# Out:
#            mpg        hp      qsec        wt
# mpg   1.000000 -0.776168  0.418684 -0.867659
# hp   -0.776168  1.000000 -0.708223  0.658748
# qsec  0.418684 -0.708223  1.000000 -0.174716
# wt   -0.867659  0.658748 -0.174716  1.000000

# %%
#using seaborn
sb.heatmap(corr,xticklabels=corr.columns.values,yticklabels=corr.columns.values)
